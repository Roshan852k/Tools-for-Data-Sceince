# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### **My name is Roshan Yadav**

# %% [markdown]
# #### _I am currently working as Analyst in my organization.I want to work in data scientist._

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Horizontal rule:
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bulleted list:
#
# 1. First item
# 2. Second item
#
# Numbered list:
#
# 1. First item
# 2. Second item
#
# This is a table:
#
# | Name | Age |
# | --- | --- |
# | Roshan  | 22 |
# | Rohan | 24 |

# %% [markdown]
# __[Open Google](https://www.google.com/search?q=www%2Cgoogle.com&rlz=1C1GCEB_enIN962IN962&oq=www%2Cgoogle.com&aqs=chrome..69i57j0i10i131i433l2j5j69i65j5i10i44l3.675j0j9&sourceid=chrome&ie=UTF-8)__
